# %%
# read neccessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
pd.options.display.max_rows = 20
np.set_printoptions(precision = 4, suppress = True)

# %% [markdown]
# ## The second sub-question
# *How much do the suicide rates differ among racial demographics (White, Black, and Hispanic) when faced with higher unemployment rates?*

# %%
file1 = 'Death_rates_for_suicide_by_sex_race_age_United_States.csv'
file2 = 'EPI Data Library - Unemployment.csv'

# %%
death_data = pd.read_csv(file1)
unemployment_data = pd.read_csv(file2)

# %%
unemployment_data
# Out:
#          Date   All Women   Men  Black Hispanic White Black Women Black Men  \
# 0    Dec-2024  4.0%  3.9%  4.1%   6.2%     5.1%  3.2%        5.8%      6.7%
# 1    Nov-2024  4.0%  3.9%  4.1%   6.1%     5.0%  3.2%        5.7%      6.6%
# 2    Oct-2024  4.0%  3.8%  4.1%   6.1%     5.0%  3.1%        5.6%      6.6%
# 3    Sep-2024  3.9%  3.8%  4.1%   6.1%     5.0%  3.1%        5.7%      6.6%
# 4    Aug-2024  3.9%  3.7%  4.1%   6.1%     4.9%  3.1%        5.6%      6.6%
# ..        ...   ...   ...   ...    ...      ...   ...         ...       ...
# 548  Apr-1979  5.9%  7.1%  5.1%  12.7%     8.8%  4.9%       14.0%     11.4%
# 549  Mar-1979  6.0%  7.2%  5.1%  12.7%     8.9%  5.0%       14.0%     11.6%
# 550  Feb-1979  6.0%  7.2%  5.2%  12.8%     9.0%  5.0%       14.1%     11.6%
# 551  Jan-1979  6.1%  7.2%  5.2%  12.8%     9.2%  5.0%       14.1%     11.6%
# 552  Dec-1978  6.1%  7.3%  5.3%  13.0%     9.3%  5.1%       14.3%     11.7%
#
#     Hispanic Women  ... White Women 55-64 White Women 65+ White Men 16-24  \
# 0             5.4%  ...              2.0%            2.7%            7.8%
# 1             5.3%  ...              2.0%            2.7%            7.7%
# 2             5.2%  ...              2.0%            2.6%            7.5%
# 3             5.1%  ...              2.1%            2.7%            7.5%
# 4             5.0%  ...              2.2%            2.6%            7.5%
# ..             ...  ...               ...             ...             ...
# 548          11.0%  ...              2.9%            3.3%            9.4%
# 549          11.2%  ...              2.9%            3.4%            9.4%
# 550          11.4%  ...              2.9%            3.4%            9.6%
# 551          11.5%  ...              2.9%            3.2%            9.7%
# 552          11.6%  ...              3.0%            3.3%            9.7%
#
#     White Men 25-54 White Men 55-64 White Men 65+  16-24 25-54 55-64   65+
# 0              2.9%            2.5%          2.8%   8.9%  3.4%  2.8%  3.1%
# 1              2.9%            2.5%          2.7%   8.9%  3.4%  2.8%  3.1%
# 2              2.8%            2.6%          2.7%   8.7%  3.4%  2.8%  3.1%
# 3              2.8%            2.5%          2.7%   8.7%  3.3%  2.8%  3.1%
# 4              2.8%            2.5%          2.7%   8.6%  3.3%  2.7%  3.0%
# ..              ...             ...           ...    ...   ...   ...   ...
# 548            2.8%            2.3%          3.5%  11.9%  4.2%  2.8%  3.7%
# 549            2.8%            2.4%          3.5%  12.0%  4.3%  2.8%  3.8%
# 550            2.8%            2.4%          3.5%  12.2%  4.3%  2.8%  3.8%
# 551            2.9%            2.5%          3.5%  12.3%  4.3%  2.9%  3.7%
# 552            2.9%            2.5%          3.6%  12.4%  4.3%  2.9%  3.8%
#
# [553 rows x 61 columns]

# %%
unemployment_data = unemployment_data[['Date', 'All', 'Black', 'White', 'Hispanic']]

# %% [markdown]
# *Delete the moth and day from the date and create another column called 'year' to make the following calculation easly*

# %%
new_unemployment_data = unemployment_data[['Date', 'All', 'Black', 'White', 'Hispanic']].copy()
new_unemployment_data['Date'] = pd.to_datetime(new_unemployment_data['Date'], format='%b-%Y')
new_unemployment_data['Year'] = new_unemployment_data['Date'].dt.year
new_unemployment_data
# Out:
#           Date   All  Black White Hispanic  Year
# 0   2024-12-01  4.0%   6.2%  3.2%     5.1%  2024
# 1   2024-11-01  4.0%   6.1%  3.2%     5.0%  2024
# 2   2024-10-01  4.0%   6.1%  3.1%     5.0%  2024
# 3   2024-09-01  3.9%   6.1%  3.1%     5.0%  2024
# 4   2024-08-01  3.9%   6.1%  3.1%     4.9%  2024
# ..         ...   ...    ...   ...      ...   ...
# 548 1979-04-01  5.9%  12.7%  4.9%     8.8%  1979
# 549 1979-03-01  6.0%  12.7%  5.0%     8.9%  1979
# 550 1979-02-01  6.0%  12.8%  5.0%     9.0%  1979
# 551 1979-01-01  6.1%  12.8%  5.0%     9.2%  1979
# 552 1978-12-01  6.1%  13.0%  5.1%     9.3%  1978
#
# [553 rows x 6 columns]

# %% [markdown]
# *Delete the '%' char from the data frame to make the following calculations easly*

# %%
for col in new_unemployment_data.columns:
    if new_unemployment_data[col].dtype == 'object':  
        new_unemployment_data[col] = new_unemployment_data[col].str.rstrip('%').astype(float)

# %% [markdown]
# *Creating a new column which includes the mean of all races in the data*

# %%
new_unemployment_data[['Year', 'All', 'Black', 'White', 'Hispanic']]
new_unemployment_data['All_demographics'] = new_unemployment_data[['Black', 'White', 'Hispanic']].mean(axis=1)
new_unemployment_data
# Out:
#           Date  All  Black  White  Hispanic  Year  All_demographics
# 0   2024-12-01  4.0    6.2    3.2       5.1  2024          4.833333
# 1   2024-11-01  4.0    6.1    3.2       5.0  2024          4.766667
# 2   2024-10-01  4.0    6.1    3.1       5.0  2024          4.733333
# 3   2024-09-01  3.9    6.1    3.1       5.0  2024          4.733333
# 4   2024-08-01  3.9    6.1    3.1       4.9  2024          4.700000
# ..         ...  ...    ...    ...       ...   ...               ...
# 548 1979-04-01  5.9   12.7    4.9       8.8  1979          8.800000
# 549 1979-03-01  6.0   12.7    5.0       8.9  1979          8.866667
# 550 1979-02-01  6.0   12.8    5.0       9.0  1979          8.933333
# 551 1979-01-01  6.1   12.8    5.0       9.2  1979          9.000000
# 552 1978-12-01  6.1   13.0    5.1       9.3  1978          9.133333
#
# [553 rows x 7 columns]

# %%
final_new_data = new_unemployment_data[['Year','All_demographics', 'Black', 'White', 'Hispanic']].copy()

# %% [markdown]
# *Making the data frame shorter by taking the avg. of every year*

# %%
final_new_data = final_new_data.groupby('Year').mean()
final_new_data.reset_index(inplace=True)

# %% [markdown]
# *Substituting the years which are not compatible with other data sets*

# %%
final_new_data = final_new_data[final_new_data['Year'] >= 1980]
final_new_data = final_new_data.loc[final_new_data['Year'] <= 2018]
final_new_data
# Out:
#     Year  All_demographics      Black     White   Hispanic
# 0   1980          9.397222  13.283333  5.516667   9.391667
# 1   1981         10.736111  15.325000  6.391667  10.491667
# 2   1982         12.308333  17.533333  7.366667  12.025000
# 3   1983         14.322222  20.033333  8.508333  14.425000
# 4   1984         12.094444  17.575000  6.891667  11.816667
# ..   ...               ...        ...       ...        ...
# 34  2014          8.619444  12.233333  5.366667   8.258333
# 35  2015          7.283333  10.508333  4.466667   6.875000
# 36  2016          6.377778   9.016667  4.025000   6.091667
# 37  2017          5.744444   7.958333  3.766667   5.508333
# 38  2018          5.077778   7.041667  3.308333   4.883333
#
# [39 rows x 5 columns]

# %% [markdown]
# *Saving the clean data to computer*

# %%
# final_new_data.to_csv(r'C:\Users\User\Desktop\bet startUp\final_data_23_24.csv', index=False)
# final_new_data.to_csv(r'C:\Users\User\Desktop\vrije\3. year\3. period\Data Wrangling\final proje\Our_final_data', index=False)
# final_new_data.to_csv(r'C:\Users\User\Desktop\final_data.csv', index=False)

# %% [markdown]
# *Making bar plot with the final data set and download it to computer*

# %%
final_new_data.plot(kind='bar', x='Year', y=['Black', 'Hispanic', 'White'], figsize=(23,6), rot=90, width=0.8, color=['#457fc0', '#df8a10', '#2fa256'])
plt.xlabel('Years')
plt.ylabel('Mean of All Demographics Based On Race')
plt.title('Mean Of All Demographics Over The Years For Unemployment')
# plt.savefig("plot.png", dpi=300, bbox_inches="tight") #to save the png file to computer

plt.show()

# %% [markdown]
# ## Second data (Deadth) ##

# %%
death_data
# Out:
#                     INDICATOR  \
# 0     Death rates for suicide
# 1     Death rates for suicide
# 2     Death rates for suicide
# 3     Death rates for suicide
# 4     Death rates for suicide
# ...                       ...
# 6385  Death rates for suicide
# 6386  Death rates for suicide
# 6387  Death rates for suicide
# 6388  Death rates for suicide
# 6389  Death rates for suicide
#
#                                                    UNIT  UNIT_NUM  \
# 0     Deaths per 100,000 resident population, age-ad...         1
# 1     Deaths per 100,000 resident population, age-ad...         1
# 2     Deaths per 100,000 resident population, age-ad...         1
# 3     Deaths per 100,000 resident population, age-ad...         1
# 4     Deaths per 100,000 resident population, age-ad...         1
# ...                                                 ...       ...
# 6385      Deaths per 100,000 resident population, crude         2
# 6386      Deaths per 100,000 resident population, crude         2
# 6387      Deaths per 100,000 resident population, crude         2
# 6388      Deaths per 100,000 resident population, crude         2
# 6389      Deaths per 100,000 resident population, crude         2
#
#                                               STUB_NAME  STUB_NAME_NUM  \
# 0                                                 Total              0
# 1                                                 Total              0
# 2                                                 Total              0
# 3                                                 Total              0
# 4                                                 Total              0
# ...                                                 ...            ...
# 6385  Sex, age and race and Hispanic origin (Single ...             11
# 6386  Sex, age and race and Hispanic origin (Single ...             11
# 6387  Sex, age and race and Hispanic origin (Single ...             11
# 6388  Sex, age and race and Hispanic origin (Single ...             11
# 6389  Sex, age and race and Hispanic origin (Single ...             11
#
#                                              STUB_LABEL  STUB_LABEL_NUM  YEAR  \
# 0                                           All persons           0.000  1950
# 1                                           All persons           0.000  1960
# 2                                           All persons           0.000  1970
# 3                                           All persons           0.000  1980
# 4                                           All persons           0.000  1981
# ...                                                 ...             ...   ...
# 6385  Female: Not Hispanic or Latino: Black or Afric...           7.225  2018
# 6386  Female: Hispanic or Latino: All races: 15-24 y...           7.232  2018
# 6387  Female: Hispanic or Latino: All races: 25-44 y...           7.233  2018
# 6388  Female: Hispanic or Latino: All races: 45-64 y...           7.234  2018
# 6389  Female: Hispanic or Latino: All races: 65 year...           7.235  2018
#
#       YEAR_NUM                AGE  AGE_NUM  ESTIMATE FLAG
# 0            1           All ages      0.0      13.2  NaN
# 1            2           All ages      0.0      12.5  NaN
# 2            3           All ages      0.0      13.1  NaN
# 3            4           All ages      0.0      12.2  NaN
# 4            5           All ages      0.0      12.3  NaN
# ...        ...                ...      ...       ...  ...
# 6385        42  65 years and over      5.0       1.3  NaN
# 6386        42        15-24 years      2.0       4.1  NaN
# 6387        42        25-44 years      3.0       4.4  NaN
# 6388        42        45-64 years      4.0       3.2  NaN
# 6389        42  65 years and over      5.0       1.6  NaN
#
# [6390 rows x 13 columns]

# %% [markdown]
# *To choose usable rows from the data set, I used unique to see all rows*

# %%
death_data['STUB_LABEL'].unique()
# Out:
# array(['All persons', 'Male', 'Female', 'Male: White',
#        'Male: Black or African American',
#        'Male: American Indian or Alaska Native',
#        'Male: Asian or Pacific Islander', 'Female: White',
#        'Female: Black or African American',
#        'Female: American Indian or Alaska Native',
#        'Female: Asian or Pacific Islander',
#        'Male: Not Hispanic or Latino: White',
#        'Male: Not Hispanic or Latino: Black or African American',
#        'Male: Hispanic or Latino: All races',
#        'Male: Not Hispanic or Latino: American Indian or Alaska Native',
#        'Male: Not Hispanic or Latino: Asian or Pacific Islander',
#        'Female: Not Hispanic or Latino: White',
#        'Female: Not Hispanic or Latino: Black or African American',
#        'Female: Hispanic or Latino: All races',
#        'Female: Not Hispanic or Latino: American Indian or Alaska Native',
#        'Female: Not Hispanic or Latino: Asian or Pacific Islander',
#        'Male: Not Hispanic or Latino: Asian',
#        'Male: Not Hispanic or Latino: Native Hawaiian or Other Pacific Islander',
#        'Female: Not Hispanic or Latino: Asian',
#        'Female: Not Hispanic or Latino: Native Hawaiian or Other Pacific Islander',
#        '10-14 years', '15-24 years', '15-19 years', '20-24 years',
#        '25-44 years', '25-34 years', '35-44 years', '45-64 years',
#        '45-54 years', '55-64 years', '65 years and over', '65-74 years',
#        '75-84 years', '85 years and over', 'Male: 10-14 years',
#        'Male: 15-24 years', 'Male: 15-19 years', 'Male: 20-24 years',
#        'Male: 25-44 years', 'Male: 25-34 years', 'Male: 35-44 years',
#        'Male: 45-64 years', 'Male: 45-54 years', 'Male: 55-64 years',
#        'Male: 65 years and over', 'Male: 65-74 years',
#        'Male: 75-84 years', 'Male: 85 years and over',
#        'Female: 10-14 years', 'Female: 15-24 years',
#        'Female: 15-19 years', 'Female: 20-24 years',
#        'Female: 25-44 years', 'Female: 25-34 years',
#        'Female: 35-44 years', 'Female: 45-64 years',
#        'Female: 45-54 years', 'Female: 55-64 years',
#        'Female: 65 years and over', 'Female: 65-74 years',
#        'Female: 75-84 years', 'Female: 85 years and over',
#        'Male: White: 15-24 years', 'Male: White: 25-44 years',
#        'Male: White: 45-64 years', 'Male: White: 65 years and over',
#        'Male: White: 65-74 years', 'Male: White: 75-84 years',
#        'Male: White: 85 years and over',
#        'Male: Black or African American: 15-24 years',
#        'Male: Black or African American: 25-44 years',
#        'Male: Black or African American: 45-64 years',
#        'Male: Black or African American: 65 years and over',
#        'Male: Black or African American: 65-74 years',
#        'Male: Black or African American: 75-84 years',
#        'Male: Black or African American: 85 years and over',
#        'Male: American Indian or Alaska Native: 15-24 years',
#        'Male: American Indian or Alaska Native: 25-44 years',
#        'Male: American Indian or Alaska Native: 45-64 years',
#        'Male: American Indian or Alaska Native: 65 years and over',
#        'Male: Asian or Pacific Islander: 15-24 years',
#        'Male: Asian or Pacific Islander: 25-44 years',
#        'Male: Asian or Pacific Islander: 45-64 years',
#        'Male: Asian or Pacific Islander: 65 years and over',
#        'Female: White: 15-24 years', 'Female: White: 25-44 years',
#        'Female: White: 45-64 years', 'Female: White: 65 years and over',
#        'Female: Black or African American: 15-24 years',
#        'Female: Black or African American: 25-44 years',
#        'Female: Black or African American: 45-64 years',
#        'Female: Black or African American: 65 years and over',
#        'Female: American Indian or Alaska Native: 15-24 years',
#        'Female: American Indian or Alaska Native: 25-44 years',
#        'Female: American Indian or Alaska Native: 45-64 years',
#        'Female: American Indian or Alaska Native: 65 years and over',
#        'Female: Asian or Pacific Islander: 15-24 years',
#        'Female: Asian or Pacific Islander: 25-44 years',
#        'Female: Asian or Pacific Islander: 45-64 years',
#        'Female: Asian or Pacific Islander: 65 years and over',
#        'Male: Not Hispanic or Latino: American Indian or Alaska Native: 15-24 years',
#        'Male: Not Hispanic or Latino: White: 15-24 years',
#        'Male: Not Hispanic or Latino: American Indian or Alaska Native: 25-44 years',
#        'Male: Not Hispanic or Latino: American Indian or Alaska Native: 45-64 years',
#        'Male: Not Hispanic or Latino: American Indian or Alaska Native: 65 years and over',
#        'Male: Not Hispanic or Latino: Asian or Pacific Islander: 15-24 years',
#        'Male: Not Hispanic or Latino: Asian or Pacific Islander: 25-44 years',
#        'Male: Not Hispanic or Latino: Asian or Pacific Islander: 45-64 years',
#        'Male: Not Hispanic or Latino: Asian or Pacific Islander: 65 years and over',
#        'Female: Not Hispanic or Latino: American Indian or Alaska Native: 15-24 years',
#        'Female: Not Hispanic or Latino: American Indian or Alaska Native: 25-44 years',
#        'Female: Not Hispanic or Latino: American Indian or Alaska Native: 45-64 years',
#        'Female: Not Hispanic or Latino: American Indian or Alaska Native: 65 years and over',
#        'Female: Not Hispanic or Latino: Asian or Pacific Islander: 15-24 years',
#        'Female: Not Hispanic or Latino: Asian or Pacific Islander: 25-44 years',
#        'Female: Not Hispanic or Latino: Asian or Pacific Islander: 45-64 years',
#        'Female: Not Hispanic or Latino: Asian or Pacific Islander: 65 years and over',
#        'Male: Not Hispanic or Latino: White: 25-44 years',
#        'Male: Not Hispanic or Latino: White: 45-64 years',
#        'Male: Not Hispanic or Latino: White: 65 years and over',
#        'Male: Not Hispanic or Latino: Black or African American: 15-24 years',
#        'Male: Not Hispanic or Latino: Black or African American: 25-44 years',
#        'Male: Not Hispanic or Latino: Black or African American: 45-64 years',
#        'Male: Not Hispanic or Latino: Black or African American: 65 years and over',
#        'Male: Hispanic or Latino: All races: 15-24 years',
#        'Male: Hispanic or Latino: All races: 25-44 years',
#        'Male: Hispanic or Latino: All races: 45-64 years',
#        'Male: Hispanic or Latino: All races: 65 years and over',
#        'Female: Not Hispanic or Latino: White: 15-24 years',
#        'Female: Not Hispanic or Latino: White: 25-44 years',
#        'Female: Not Hispanic or Latino: White: 45-64 years',
#        'Female: Not Hispanic or Latino: White: 65 years and over',
#        'Female: Not Hispanic or Latino: Black or African American: 15-24 years',
#        'Female: Not Hispanic or Latino: Black or African American: 25-44 years',
#        'Female: Not Hispanic or Latino: Black or African American: 45-64 years',
#        'Female: Not Hispanic or Latino: Black or African American: 65 years and over',
#        'Female: Hispanic or Latino: All races: 15-24 years',
#        'Female: Hispanic or Latino: All races: 25-44 years',
#        'Female: Hispanic or Latino: All races: 45-64 years',
#        'Female: Hispanic or Latino: All races: 65 years and over',
#        'Male: Not Hispanic or Latino: Asian: 15-24 years',
#        'Male: Not Hispanic or Latino: Asian: 25-44 years',
#        'Male: Not Hispanic or Latino: Asian: 45-64 years',
#        'Male: Not Hispanic or Latino: Asian: 65 years and over',
#        'Male: Not Hispanic or Latino: Native Hawaiian or Other Pacific Islander: 15-24 years',
#        'Male: Not Hispanic or Latino: Native Hawaiian or Other Pacific Islander: 25-44 years',
#        'Male: Not Hispanic or Latino: Native Hawaiian or Other Pacific Islander: 45-64 years',
#        'Male: Not Hispanic or Latino: Native Hawaiian or Other Pacific Islander: 65 years and over',
#        'Female: Not Hispanic or Latino: Asian: 15-24 years',
#        'Female: Not Hispanic or Latino: Asian: 25-44 years',
#        'Female: Not Hispanic or Latino: Asian: 45-64 years',
#        'Female: Not Hispanic or Latino: Asian: 65 years and over',
#        'Female: Not Hispanic or Latino: Native Hawaiian or Other Pacific Islander: 15-24 years',
#        'Female: Not Hispanic or Latino: Native Hawaiian or Other Pacific Islander: 25-44 years',
#        'Female: Not Hispanic or Latino: Native Hawaiian or Other Pacific Islander: 45-64 years',
#        'Female: Not Hispanic or Latino: Native Hawaiian or Other Pacific Islander: 65 years and over'],
#       dtype=object)

# %%
death_data_new = death_data[['YEAR', 'STUB_LABEL', 'ESTIMATE']]
death_data_new
# Out:
#       YEAR                                         STUB_LABEL  ESTIMATE
# 0     1950                                        All persons      13.2
# 1     1960                                        All persons      12.5
# 2     1970                                        All persons      13.1
# 3     1980                                        All persons      12.2
# 4     1981                                        All persons      12.3
# ...    ...                                                ...       ...
# 6385  2018  Female: Not Hispanic or Latino: Black or Afric...       1.3
# 6386  2018  Female: Hispanic or Latino: All races: 15-24 y...       4.1
# 6387  2018  Female: Hispanic or Latino: All races: 25-44 y...       4.4
# 6388  2018  Female: Hispanic or Latino: All races: 45-64 y...       3.2
# 6389  2018  Female: Hispanic or Latino: All races: 65 year...       1.6
#
# [6390 rows x 3 columns]

# %% [markdown]
# *Creating a data frame that only includes necessary rows from data*
#
# *Substituting the data after the year 1980 to make the data compatible with other data sets*

# %%
selected_labels = [
    'Male: White', 
    'Male: Black or African American', 
    'Male: Hispanic or Latino: All races', 
    'Female: White',  
    'Female: Black or African American', 
    'Female: Hispanic or Latino: All races'
]

death_data_new = death_data_new[death_data_new['STUB_LABEL'].isin(selected_labels)]
death_data_new = death_data_new[death_data_new['YEAR'] >= 1980]
death_data_new = death_data_new.sort_values(by=['YEAR', 'STUB_LABEL'])

death_data_new
# Out:
#       YEAR                             STUB_LABEL  ESTIMATE
# 339   1980      Female: Black or African American       2.4
# 2915  1980      Female: Black or African American       2.2
# 716   1980  Female: Hispanic or Latino: All races       NaN
# 4887  1980  Female: Hispanic or Latino: All races       NaN
# 297   1980                          Female: White       6.1
# ...    ...                                    ...       ...
# 6332  2018    Male: Hispanic or Latino: All races      11.5
# 167   2018                            Male: White      25.5
# 796   2018                            Male: White      25.6
# 2743  2018                            Male: White      26.6
# 6294  2018                            Male: White      26.9
#
# [480 rows x 3 columns]

# %% [markdown]
# *Save the clean data set to the computer*

# %%
# death_data_new.to_csv(r'C:\Users\User\Desktop\final_data_death2.csv', index=False)

# %% [markdown]
# *Using map to collect different rows into one row under the new column called 'GROUPED_LABEL', then using groupby to calculate the mean estimate for each group by years.*

# %%
mapping = {
    'Male: White': 'White',
    'Female: White': 'White',
    'Male: Black or African American': 'Black',
    'Female: Black or African American': 'Black',
    'Male: Hispanic or Latino: All races': 'Hispanic',
    'Female: Hispanic or Latino: All races': 'Hispanic'
}

death_data_new['GROUPED_LABEL'] = death_data_new['STUB_LABEL'].map(mapping)
death_data_grouped = death_data_new.groupby(['YEAR', 'GROUPED_LABEL'], as_index=False)['ESTIMATE'].mean()
death_data_grouped
# Out:
#      YEAR GROUPED_LABEL  ESTIMATE
# 0    1980         Black    6.5750
# 1    1980      Hispanic       NaN
# 2    1980         White   13.2000
# 3    1981         Black    6.6500
# 4    1981      Hispanic       NaN
# ..    ...           ...       ...
# 112  2017      Hispanic    6.7750
# 113  2017         White   16.3000
# 114  2018         Black    7.2500
# 115  2018      Hispanic    7.3000
# 116  2018         White   16.6375
#
# [117 rows x 3 columns]

# %% [markdown]
# *Creating a new data set that races as columns and creating a new column called 'All_demographics_sui' which includes the means*

# %%
death_data_pivot = death_data_grouped.pivot(index='YEAR', columns='GROUPED_LABEL', values='ESTIMATE')
death_data_pivot['All_demographics_sui'] = death_data_pivot.mean(axis=1)
death_data_grouped_new = death_data_pivot.reset_index()

death_data_grouped_new
# Out:
# GROUPED_LABEL  YEAR  Black  Hispanic    White  All_demographics_sui
# 0              1980  6.575       NaN  13.2000              9.887500
# 1              1981  6.650       NaN  13.3750             10.012500
# 2              1982  6.475       NaN  13.6500             10.062500
# 3              1983  6.350       NaN  13.5500              9.950000
# 4              1984  6.725       NaN  13.8500             10.287500
# ..              ...    ...       ...      ...                   ...
# 34             2014  5.725     6.100  15.2500              9.025000
# 35             2015  5.775     6.025  15.5750              9.125000
# 36             2016  6.275     6.525  15.7000              9.500000
# 37             2017  6.850     6.775  16.3000              9.975000
# 38             2018  7.250     7.300  16.6375             10.395833
#
# [39 rows x 5 columns]

# %% [markdown]
# *Using pivot table to readjust numerical values and adding the estimates for each group. Also creating a bar plot with bars*
#
# *Also download the png file to the computer*

# %%
death_data_pivot = death_data_grouped.pivot_table(index='YEAR', columns='GROUPED_LABEL', values='ESTIMATE', aggfunc='sum')
death_data_pivot.plot(kind='bar', figsize=(23,6), rot=90, width=0.8)
plt.xlabel('Years')
plt.ylabel('Mean of All Demographics Based On Races')
plt.title('Mean Of All Demographics Over The Years For Suicide')
# plt.savefig("plot.png", dpi=300, bbox_inches="tight")

plt.show()
